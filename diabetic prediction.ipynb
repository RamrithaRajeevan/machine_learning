# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("diabetes_prediction_dataset.csv")
data
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
data["diabetes"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data.shape
# Out:
# (100000, 9)

# %%
data.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=100000, step=1)

# %%
data.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
data.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
l=['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
       'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes']
for i in l:
    data[i]=le.fit_transform(data[i])
data
# Out:
#        gender  age  hypertension  heart_disease  smoking_history   bmi  \
# 0           0  101             0              1                4  1334
# 1           0   75             0              0                0  1547
# 2           1   49             0              0                4  1547
# 3           0   57             0              0                1  1160
# 4           1   97             1              1                1   829
# ...       ...  ...           ...            ...              ...   ...
# 99995       0  101             0              0                0  1547
# 99996       0   23             0              0                0   552
# 99997       1   87             0              0                3  1598
# 99998       0   45             0              0                4  2357
# 99999       0   78             0              0                1  1058
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0               11                    6         0
# ...

# %%
x=data.drop("diabetes",axis=1)
x
# Out:
#        gender  age  hypertension  heart_disease  smoking_history   bmi  \
# 0           0  101             0              1                4  1334
# 1           0   75             0              0                0  1547
# 2           1   49             0              0                4  1547
# 3           0   57             0              0                1  1160
# 4           1   97             1              1                1   829
# ...       ...  ...           ...            ...              ...   ...
# 99995       0  101             0              0                0  1547
# 99996       0   23             0              0                0   552
# 99997       1   87             0              0                3  1598
# 99998       0   45             0              0                4  2357
# 99999       0   78             0              0                1  1058
#
#        HbA1c_level  blood_glucose_level
# 0               11                    6
# ...

# %%
y=data["diabetes"]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    0
# 99998    0
# 99999    0
# Name: diabetes, Length: 100000, dtype: int64

# %%
import seaborn as sns
sns.pairplot(data)
plt.show()
# Out:
# C:\Users\Lenovo\a\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data.plot("hypertension","diabetes",c="red")
# Out:
# <Axes: xlabel='hypertension'>

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=20)

# %%
from sklearn.tree import DecisionTreeClassifier
clss=DecisionTreeClassifier(criterion="entropy")

# %%
clss.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn.metrics import accuracy_score

# %%
d1=clss.predict(xtest)
d1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
a1=accuracy_score(ytest,d1)*100
a1
# Out:
# 95.065

# %%
d2=clss.predict(xtrain)
d2
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
a2=accuracy_score(ytrain,d2)*100
a2
# Out:
# 99.925

# %%
v=[[0,101,0,1,4,1334,11,6]]
w=clss.predict(v)
w
# Out:
# C:\Users\Lenovo\a\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
if w==0:
    print("Not diabetic")
else:
    print("Diabetes")
# Out:
# Not diabetic

# %%
from sklearn import tree
plt.figure(figsize=(30,25))
tree.plot_tree(clss,feature_names=x.columns.tolist(),filled=True,max_depth=18)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
d3=rf.predict(xtest)
d3
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
a3=accuracy_score(ytest,d3)*100
a3
# Out:
# 97.0

# %%
d4=rf.predict(xtrain)
d4
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
a4=accuracy_score(ytrain,d4)*100
a4
# Out:
# 99.92375

# %%
v=[[0,101,0,1,4,1334,11,6]]
w=rf.predict(v)
w
# Out:
# C:\Users\Lenovo\a\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
if w==0:
    print("Not diabetic")
else:
    print("Diabetes")
# Out:
# Not diabetic

# %%
from sklearn.svm import SVC

# %%
sv=SVC()

# %%
sv.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
d5=sv.predict(xtest)
d5
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
a5=accuracy_score(ytest,d5)*100
a5
# Out:
# 91.56

# %%
d6=sv.predict(xtrain)
d6
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
a6=accuracy_score(ytrain,d6)*100
a6
# Out:
# 91.485

# %%
v=[[0,101,0,1,4,1334,11,6]]
w=sv.predict(v)
w
# Out:
# C:\Users\Lenovo\a\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
if w==0:
    print("Not diabetic")
else:
    print("Diabetes")
# Out:
# Not diabetic

# %%
from xgboost import XGBClassifier

# %%
xg=XGBClassifier()

# %%
xg.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
d7=xg.predict(xtest)
d7
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
a7=accuracy_score(ytest,d7)*100
a7
# Out:
# 97.165

# %%
d8=xg.predict(xtrain)
d8
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
a8=accuracy_score(ytrain,d8)*100
a8
# Out:
# 97.555

# %%
v=[[0,101,0,1,4,1334,11,6]]
w=xg.predict(v)
w
# Out:
# array([0])
